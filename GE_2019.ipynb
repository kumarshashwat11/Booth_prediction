# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame, Series

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-aba14dd1-e2c0-41e5-8364-3bf2c938c7f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aba14dd1-e2c0-41e5-8364-3bf2c938c7f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_19= pd.read_csv("/content/ge_2019_wide_form.csv")

# %%
df_19.head()
# Out:
#      district  pc_no      pc_name block_code block_munc  level gp_code  \
# 0  COOCHBEHAR      3  Jalpaiguri        2853  MEKLIGANJ  Block  109011
# 1  COOCHBEHAR      3  Jalpaiguri        2853  MEKLIGANJ  Block  109011
# 2  COOCHBEHAR      3  Jalpaiguri        2853  MEKLIGANJ  Block  109011
# 3  COOCHBEHAR      3  Jalpaiguri        2853  MEKLIGANJ  Block  109011
# 4  COOCHBEHAR      3  Jalpaiguri        2853  MEKLIGANJ  Block  109011
#
#     gp_ward   type  org_block  ...  \
# 0  RANIRHAT  Rural  Mekliganj  ...
# 1  RANIRHAT  Rural  Mekliganj  ...
# 2  RANIRHAT  Rural  Mekliganj  ...
# 3  RANIRHAT  Rural  Mekliganj  ...
# 4  RANIRHAT  Rural  Mekliganj  ...
#
#                                           booth_name  total_votes  AITC  BJP  \
# 0       Chhat Dhulia Baldiahati Aided Primary School          664   44%  51%
# 1                                      Tarun S. S. K          631   44%  51%
# 2  142 Kamat Changrabandha Fifth Plan Primary School          686   44%  50%
# ...

# %%
df_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76532 entries, 0 to 76531
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   district       76532 non-null  object
#  1   pc_no          76532 non-null  int64
#  2   pc_name        76532 non-null  object
#  3   block_code     76532 non-null  object
#  4   block_munc     76532 non-null  object
#  5   level          76532 non-null  object
#  6   gp_code        76532 non-null  object
#  7   gp_ward        76532 non-null  object
#  8   type           76532 non-null  object
#  9   org_block      76532 non-null  object
#  10  ac_name        76532 non-null  object
#  11  ac_no          76532 non-null  int64
#  12  booth_no       76532 non-null  int64
#  13  booth_name     76532 non-null  object
#  14  total_votes    76532 non-null  int64
#  15  AITC           76532 non-null  object
#  16  BJP            76532 non-null  object
# ...
